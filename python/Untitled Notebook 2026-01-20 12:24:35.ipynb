# %% [markdown]
# This is a test PySpark routine to see if it is working

# %%
# Check Spark session
spark
from pyspark.sql import Row

# Create a small DataFrame
data = [Row(id=1, value="a"), Row(id=2, value="b")]
df = spark.createDataFrame(data)

df.show()

# %%
# %sql
SELECT * FROM global_temp.test_table;
